# %% [markdown]
# Task 1: The "Truthy/Falsy" Validation Suite

# %%
# Variable Setup
val_1 = 0
val_2 = 0.0
val_3 = ""
val_4 = None
val_5 = "False"

# %%
if val_1:
    print(f"Variable val_1 with value {val_1} is evaluated as TRUE")
else:
    print(f"Variable val_1 with value {val_1} is evaluated as FALSE")
# Out:
# Variable val_1 with value 0 is evaluated as FALSE

# %%
if val_2:
    print(f"Variable val_2 with value {val_2} is evaluated as TRUE")
else:
    print(f"Variable val_2 with value {val_2} is evaluated as FALSE")
# Out:
# Variable val_2 with value 0.0 is evaluated as FALSE

# %%
if val_3:
    print(f"Variable val_3 with value '{val_3}' is evaluated as TRUE")
else:
    print(f"Variable val_3 with value '{val_3}' is evaluated as FALSE")
# Out:
# Variable val_3 with value '' is evaluated as FALSE

# %%
if val_4:
    print(f"Variable val_4 with value {val_4} is evaluated as TRUE")
else:
    print(f"Variable val_4 with value {val_4} is evaluated as FALSE")
# Out:
# Variable val_4 with value None is evaluated as FALSE

# %%
if val_5:
    print(f"Variable val_5 with value '{val_5}' is evaluated as TRUE")
else:
    print(f"Variable val_5 with value '{val_5}' is evaluated as FALSE")
# Out:
# Variable val_5 with value 'False' is evaluated as TRUE

# %% [markdown]
# Task 2: Multi-Tiered Logical Branching (The Tax Engine)

# %%
annual_income = float(input("Enter Annual Income: "))
residency_status = input("Enter Residency Status (Resident/Non-Resident): ")

# Tax 
if annual_income <= 30000:
    tax_rate = 0
elif annual_income <= 80000:
    if residency_status == "Resident":
        tax_rate = 10
    else:
        tax_rate = 15
else:
    tax_rate = 25

# Calculation
tax_amount = annual_income * tax_rate / 100
remaining_balance = annual_income - tax_amount

# Output
print(f"Income: {annual_income}")
print(f"Applied Tax Rate: {tax_rate}%")
print(f"Final Balance after Tax: {remaining_balance}")
# Out:
# Income: 45000.0
# Applied Tax Rate: 15%
# Final Balance after Tax: 38250.0

# %% [markdown]
# Task 3: Modern Pattern Matching (match-case)

# %%
status_code = int(input("Enter HTTP Status Code: "))

# match-case 
match status_code:
    case 200:
        print("Success: OK")
    case 400:
        print("Client Error: Bad Request")
    case 404:
        print("Client Error: Not Found")
    case 500:
        print("Server Error: Internal Server Error")
    case _:
        print("Unknown Status Code")
# Out:
# Client Error: Bad Request

# %% [markdown]
# Task 4: Structural Pattern Matching with Combined Patterns

# %%
file_ext = input("Enter File Extension (e.g., .jpg, .pdf): ")

match file_ext:
    case ".jpg" | ".jpeg" | ".png":
        print("File Type: Image")
    case ".pdf" | ".docx" | ".txt":
        print("File Type: Document")
    case ".mp4" | ".mkv":
        print("File Type: Video")
    case _:
        print("File Type: Unsupported")
# Out:
# File Type: Image

# %% [markdown]
# Task 5: The "Short-Circuit" Logic Challenge

# %%
is_admin = input("Are you admin? (True/False): ") 
has_security_key = input("Do you have security key? (True/False): ") 
system_offline = input("Is system offline? (True/False): ") 



if (is_admin and has_security_key) or system_offline:
    print("OVERRIDE ACCESS GRANTED")
else:
    print("ACCESS DENIED")
# Out:
# OVERRIDE ACCESS GRANTED
